# %% [markdown]
# ## Fig 1
#
# plot: x-axis: epoch, y-axis: accuracy;  2 conditions: 1:50, full decolle, decolle+stdp.

# %%
def plotStats(NAME_MODEL, PATH_checkpoints):

    import pandas as pd
    import matplotlib.pyplot as plt

    # Read the input text file
    file_accuracy = f'{PATH_checkpoints}/accuracy.txt'
    data = pd.read_fwf(file_accuracy, header=0)

    # Extract train and test columns
    train_accuracy = [0.1] + data['Train'].tolist()
    test_accuracy = [0.1] + data['Test'].tolist()

    # Plotting
    plt.figure(figsize=(10, 6))
    plt.plot(train_accuracy, label='Train Accuracy', marker='o')
    plt.plot(test_accuracy, label='Test Accuracy', marker='o')

    # Add labels and title
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(NAME_MODEL)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

PATH_checkpoints = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData"


file1_accuracy = f'{PATH_checkpoints}/accuracy_1to50.txt'
data1 = pd.read_fwf(file1_accuracy, header=0)
# Extract train and test columns
test_accuracies_stdp = [0.1] + data1['Test'].tolist()

file2_accuracy = f'{PATH_checkpoints}/accuracy_fullDecolle_1to50.txt'
data2 = pd.read_fwf(file2_accuracy, header=0)
test_accuracies_decolle = [0.1] + data2['Test'].tolist()


plt.title("Test Accuracy over Epochs, 1 to 50 expansion ratio")

plt.plot(range(len(test_accuracies_stdp)), test_accuracies_stdp, label= "decolle + STDP"  )
plt.plot(range(len(test_accuracies_decolle)), test_accuracies_decolle, label= "decolle" )
plt.grid(True)
plt.legend()

plt.show()

# %%
# last_accuracy_byRatio_stdp = [0.300000, 0.395000, 0.467000, 0.541000]
# last_accuracy_byRatio_decolle = [0.479000, 0.572000, 0.508000, 0.546000]

fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the figure size according to your preference

ax.plot(range(len(test_accuracies_decolle)), test_accuracies_decolle, label= "DECOLLE" )
ax.plot(range(len(test_accuracies_stdp)), test_accuracies_stdp, label= "DECOLLE + STDP"  )
ax.legend()
ax.set_xlabel("Epoch")
ax.set_ylabel("Test-set Accuracy")
ax.set_ylim(0, 1)

# ax.set_xticks(range(len(last_accuracy_byRatio_decolle)))
# ax.set_xticklabels(['1:1', '1:10', '1:50', '1:100'])

# Add gridlines for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Customize font sizes for better readability in paper
plt.rc('font', size=12)
plt.rc('axes', titlesize=14)
plt.rc('axes', labelsize=12)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('legend', fontsize=10)

# Add a title if needed

# plt.title("Performance during Training")

plt.savefig("PerformanceDuringTraining.png", dpi=300)

# Adjust layout for better spacing
plt.tight_layout()

# %% [markdown]
# ## Fig 2
#  plot: x-axis: expansion ratio, y-axis: test accuracy on last epoch; 10 conditions: 5 expansion ratios for full decolle (blue) and decolle + stdp (orange).

# %%
# accuracy at last epoch by ratio, starting at 1to1

# fill by hand from accuracy text files
last_accuracy_byRatio_stdp = [0.300000, 0.395000, 0.467000, 0.541000]
last_accuracy_byRatio_decolle = [0.479000, 0.572000, 0.508000, 0.546000]

plt.plot(range(len(last_accuracy_byRatio_stdp)), last_accuracy_byRatio_stdp, marker = "o", label= "decolle + STDP")
plt.plot(range(len(last_accuracy_byRatio_decolle)), last_accuracy_byRatio_decolle, marker = "o", label= "decolle")
plt.legend()
plt.xlabel("Expansion Ratio")
plt.ylabel("Test Accuracy in last epoch")

plt.xticks(range(len(last_accuracy_byRatio_decolle)), ['1:1', '1:10', '1:50', '1:100'])
# Out:
# ([<matplotlib.axis.XTick at 0x7f2c3db554e0>,
# ...
#  [Text(0, 0, '1:1'),
#   Text(1, 0, '1:10'),
#   Text(2, 0, '1:50'),
#   Text(3, 0, '1:100')])

# %%
last_accuracy_byRatio_stdp = [0.300000, 0.395000, 0.467000, 0.541000]
last_accuracy_byRatio_decolle = [0.479000, 0.572000, 0.508000, 0.546000]

fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the figure size according to your preference

ax.plot(range(len(last_accuracy_byRatio_decolle)), last_accuracy_byRatio_decolle, marker="o", label="SNN gradient-based")
ax.plot(range(len(last_accuracy_byRatio_stdp)), last_accuracy_byRatio_stdp, marker="o", label="SNN gradient-based + Hebbian")
ax.scatter(2, 0.75, marker= "s", label= "FNN", color= "green")

ax.legend()
ax.set_xlabel("Expansion Ratio")
ax.set_ylabel("Accuracy")
ax.set_ylim(0.1, 0.9)

ax.set_xticks(range(len(last_accuracy_byRatio_decolle)))
ax.set_xticklabels(['1:1', '1:10', '1:50', '1:100'])



# Add gridlines for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Customize font sizes for better readability in paper
plt.rc('font', size=12)
plt.rc('axes', titlesize=14)
plt.rc('axes', labelsize=12)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('legend', fontsize=10)

# Add a title if needed

# plt.title("Performance by Expansion Ratio")

plt.savefig("PerformanceByExpansion.png", dpi=300)

# Adjust layout for better spacing
plt.tight_layout()

# %%
import numpy as np
last_accuracy_byRatio_stdp = [0.300000, 0.395000, 0.467000, 0.541000]
last_accuracy_byRatio_decolle = [0.479000, 0.572000, 0.508000, 0.546000]

fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the figure size according to your preference
bar_width = 0.35


# Use bar plots instead of line plots
ax.bar(range(len(last_accuracy_byRatio_decolle)), last_accuracy_byRatio_decolle, width=bar_width, label="SNN - DECOLLE")
ax.bar(np.arange(len(last_accuracy_byRatio_stdp)) + bar_width, last_accuracy_byRatio_stdp, width=bar_width, label="SNN - DECOLLE + STDP")

# Highlight FNN with a different marker and color
# ax.scatter(2, 0.75, color="green", label="FNN", marker="_", s= 10000)
ax.axhline(0.75, linestyle='dashed', color="green", label= "ANN")

ax.legend()
ax.set_xlabel("Expansion Ratio")
ax.set_ylabel("Accuracy")
ax.set_ylim(0.1, 0.9)

ax.set_xticks(range(len(last_accuracy_byRatio_decolle)))
ax.set_xticklabels(['1:1', '1:10', '1:50', '1:100'])

# Add gridlines for better readability
ax.grid(True, linestyle='--', alpha=0.7)

# Customize font sizes for better readability in paper
plt.rc('font', size=12)
plt.rc('axes', titlesize=14)
plt.rc('axes', labelsize=12)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('legend', fontsize=10)

plt.savefig("PerformanceByExpansion.png", dpi=300)

# %% [markdown]
# ### Calculating correlation between expansion ratio and performance

# %%
import scipy.stats

expansion_ratios = [1, 10, 50, 100]

print("correlation for gradient-based + Hebbian:", scipy.stats.pearsonr(expansion_ratios, last_accuracy_byRatio_stdp))

print("correlation for gradient-based:", scipy.stats.pearsonr(expansion_ratios, last_accuracy_byRatio_decolle))
# Out:
# correlation for gradient-based + Hebbian: PearsonRResult(statistic=0.9437163873586951, pvalue=0.05628361264130488)
# correlation for gradient-based: PearsonRResult(statistic=0.2649322194040934, pvalue=0.7350677805959065)

# %% [markdown]
# ## Fig 3
#
# B) x_axis: expansion ratio, y-axis: final GloScore; (decolle + stdp)

# %% [markdown]
# ### Defining network - run and ignore

# %%
import numpy as np
from numpy import save
from numpy import load
from sklearn.metrics.pairwise import euclidean_distances
import matplotlib.pyplot as plt

import torch
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader
import lava.lib.dl.slayer as slayer
from tqdm import tqdm
import os
from loss import DECOLLELoss
from assistant_fixed import HybridAssistant
from torch.nn.functional import one_hot


class HybridNetwork(torch.nn.Module):
    def __init__(self, layer_sizes,
                 n_class, stdp_block_idx, stdp_learning_rate,
                 stdp_tau_combined, burn_in=0):

        super(HybridNetwork, self).__init__()

        self.burn_in = burn_in
        self.stdp_learning_rate = stdp_learning_rate
        self.stdp_tau_combined = stdp_tau_combined
        self.layer_sizes = layer_sizes

        assert stdp_block_idx < len(layer_sizes), 'STDP block position exceeds the number of layers'
        # Defining which of the layers to not give linear readouts to.
        # Make an exception for the last layer (always has one) and ignore the
        # input layer (no weights to train there)
        self.stdp_block_idx = stdp_block_idx

        no_readouts = np.zeros(len(layer_sizes)-1)
        for i in range(len(no_readouts)):
            if i == self.stdp_block_idx and i < len(no_readouts)-1:
                no_readouts[i] = 1

        self.no_readouts = no_readouts

        # Input neuron parameters, threshold set to 1 as per course guidelines
        input_neuron_parameters = {
            'threshold': 1.,
            'current_decay': 0.25,
            'voltage_decay': 0.03,
            'tau_grad': 0.03,
            'scale_grad': 3.,
            'requires_grad': True,
            'persistent_state': True
        }
        # Default values in SLAYER and DECOLLE notebooks
        neuron_parameters = {
            'threshold': 1.25,
            'current_decay': 0.25,
            'voltage_decay': 0.03,
            'tau_grad': 0.03,
            'scale_grad': 3.,
            'requires_grad': True,
            'persistent_state': True
        }
        # Defining layers. Start with an input layer that is always the same
        # (defined separately to make dataset work)
        blocks = [slayer.block.cuba.Dense(
            input_neuron_parameters, layer_sizes[0], layer_sizes[1], weight_norm=False)]

        for i in range(1, len(layer_sizes)-1):
            blocks.append(slayer.block.cuba.Dense(
                neuron_parameters, layer_sizes[i],
                layer_sizes[i+1], weight_norm=False))

        self.blocks = torch.nn.ModuleList(blocks)

        # Removing gradient dependence if STDP block
        self.blocks[self.stdp_block_idx].synapse.weight.requires_grad=False

        #TODO: Figure out the batch norm thing if possible


        # Defining random readouts for each layer, unless specifically ignored
        readout_layers = []
        for layer_size, no_readout in zip(layer_sizes[1:], self.no_readouts):
            if not no_readout:
                readout_layers.append(torch.nn.Linear(layer_size, n_class, bias=False))
        self.readout_layers = torch.nn.ModuleList(readout_layers)

        for readout_layer in self.readout_layers:
            readout_layer.weight.requires_grad = False

    def forward(self, spike):
        # First we pass the input through all of the layers and get the
        # corresponding output at each layer, then we iterate through
        # these layers linear readout layers as well. Gradient descent is only
        # performed on the blocks for which we have a linear readout on the
        # output, therefore not having a readout for the STDP block means
        # gradient updates are not performed there.

        spike.requires_grad_()
        gd_spikes = [] # used for gradient descent
        all_spikes = [] # all spikes within the model
        readouts = []
        voltages = []
        spike_counts = []

        for i, layer in enumerate(self.blocks):
            # Getting voltage at each postsynaptic neuron corresponding to input
            z = layer.synapse(spike.detach())
            _, voltage = layer.neuron.dynamics(z)
            # Getting the spikes that result from the voltage at these neurons
            spike = layer.neuron.spike(voltage)

            # Only keeping track of spikes for layers where we want to perform
            # backprop (makes getting readouts easier)
            if not i == self.stdp_block_idx:
                gd_spikes.append(spike)

            all_spikes.append(spike)
            voltages.append(voltage)
            spike_counts.append(torch.mean(spike.detach()))

        for readout_layer, spike in zip(self.readout_layers, gd_spikes):
            # Getting a linear readout of the layer
            readout = []
            for t in range(spike.shape[-1]):
                readout.append(readout_layer(spike[..., t]))
            readouts.append(torch.stack(readout, dim=-1))

        return all_spikes, readouts, voltages, spike_counts

    def reset_(self):
        # Resetting the state of the network
        for layer in self.blocks:
            layer.neuron.current_state[:] = 0
            layer.neuron.voltage_state[:] = 0

    def init_state(self, inputs, burn_in=None):
        # Resets the network state, and applies an initial burn-in period
        # by passing the first few timepoints of the input through the network
        self.reset_()
        if burn_in is None:
            burn_in = self.burn_in
        self.forward(inputs[..., :burn_in])

        return inputs[..., :burn_in]

    def plot_weights(self, block_idx):
        plt.figure()
        layer_params = self.blocks[block_idx].synapse.weight.data
        weight_matrix = np.squeeze(layer_params.numpy())
        plt.imshow(weight_matrix, aspect='auto')
        plt.colorbar(shrink = 0.8, label = 'Weight')
        plt.title(f'Weights for block {block_idx}')
        plt.xlabel('Presynaptic neurons')
        plt.ylabel('Postsynaptic neurons')

    def print_weights(self, block_idx):
        print(np.squeeze(self.blocks[block_idx].synapse.weight.data.numpy()))

# %% [markdown]
# ### Getting GloScores

# %% [markdown]
# #### Get GloScores hybrid

# %%
# code from Laurens
import torch
file1to1 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to1_30epochs_epoch_29.pt"
file1to10 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to10_30epochs_epoch_29.pt"
file1to50 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to50_30epochs_epoch_29.pt"
file1to100 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to100_30epochs_epoch_29.pt"

# %%
n_train = 2500 # 1,000,000 in the original paper
n_val = 1000 # 8192 in the original paper
n_prot = 20 # 200 prototypes in the original paper
n_class = 10 # 100 classes in the original paper

n_timepoints = 150 # Number of timepoints per sample in the dataset
batch_size = 256

stdp_learning_rate = 0.002 # See my message
stdp_tau_combined = -.6    # See my message
stdp_block_idx = 2  # The index of the block on which STDP will be performed (3 blocks total)

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device=torch.device('cpu')

gloscores_hybrid = []


files = [file1to1, file1to10, file1to50, file1to100]
files_paths = [file1to1, file1to10, file1to50, file1to100]


for index, file in enumerate(files_paths):
    print(file)
    filename = files[index]
    expansion = filename.split("_")[1]
    if len(filename.split("_")) > 3:
        epoch = int(filename.split("_")[-1][0:-3])
        name = f"epoch{epoch:02} expansion{expansion}"
    else:
        epoch = 30
        name = f"epoch{epoch:02} expansion{expansion}"
        
    file_contents = torch.load(f= file, map_location=torch.device('cpu'))
    expansion_block = file_contents['blocks.2.synapse.weight']

    layer_sizes = [50, 500, 50, len(expansion_block)] # These are same as the original

    hybrid_network = HybridNetwork(layer_sizes, n_class, stdp_block_idx, stdp_learning_rate, stdp_tau_combined, burn_in=50).to(device)
    hybrid_network.load_state_dict(file_contents)

    first_block = np.squeeze(hybrid_network.blocks[0].synapse.weight.data.cpu().numpy())
    OR_assignment = [np.argmax(i) for i in first_block]
    ORN_first_three = [[i[-1], i[-2], i[-3]] for i in np.sort(first_block)]

    
    
    second_block = np.squeeze(hybrid_network.blocks[1].synapse.weight.data.cpu().numpy())
    PN_gloscores = np.zeros(len(second_block))
    for PN_index, PN in enumerate(second_block):
        # Each PN needs its own ORN ranking
        second_block_ORN_weights = second_block[PN_index]
        average_ORN_by_type = {}
        for OR_index in range(len(first_block[0])):
            # Each OR needs an average value
            total = []
            for i in range(len(OR_assignment)):
                # Each average comes from the assignment
                if OR_assignment[i] == OR_index:
                    total.append(second_block_ORN_weights[i])
            if len(total) != 0:
                average_ORN_by_type[OR_index] = sum(total)/len(total)
            else:
                average_ORN_by_type[OR_index] = 0
        # Sort the averages so we can take the last two
        sorted_averages = sorted(average_ORN_by_type.items(), key = lambda x: x[1])
        weight_1 = sorted_averages[-1][1]
        weight_2 = sorted_averages[-2][1]
        PN_gloscores[PN_index] = (weight_1-weight_2)/(weight_1+weight_2)
    gloscores_hybrid.append(np.average(PN_gloscores))
    # sorted_gloscores = dict(sorted(gloscores.items(), key = lambda x: x[0]))
# Out:
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to1_30epochs_epoch_29.pt
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to10_30epochs_epoch_29.pt
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to50_30epochs_epoch_29.pt
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to100_30epochs_epoch_29.pt

# %% [markdown]
# #### getting Gloscores DECOLLE

# %%
# code from Laurens
import torch
file1to1 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to1_30epochs_epoch_29.pt"
file1to10 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to10_30epochs_epoch_29.pt"
file1to50 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to50_30epochs_epoch_29.pt"
file1to100 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to100_30epochs_epoch_29.pt"

# %%
n_train = 2500 # 1,000,000 in the original paper
n_val = 1000 # 8192 in the original paper
n_prot = 20 # 200 prototypes in the original paper
n_class = 10 # 100 classes in the original paper

n_timepoints = 150 # Number of timepoints per sample in the dataset
batch_size = 256

stdp_learning_rate = 0.002 # See my message
stdp_tau_combined = -.6    # See my message
stdp_block_idx = 2  # The index of the block on which STDP will be performed (3 blocks total)

if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device=torch.device('cpu')

gloscores_decolle = []


files = [file1to1, file1to10, file1to50, file1to100]
files_paths = [file1to1, file1to10, file1to50, file1to100]


for index, file in enumerate(files_paths):
    print(file)
    filename = files[index]
    expansion = filename.split("_")[1]
    if len(filename.split("_")) > 3:
        epoch = int(filename.split("_")[-1][0:-3])
        name = f"epoch{epoch:02} expansion{expansion}"
    else:
        epoch = 30
        name = f"epoch{epoch:02} expansion{expansion}"
        
    file_contents = torch.load(f= file, map_location=torch.device('cpu'))
    expansion_block = file_contents['blocks.2.synapse.weight']

    layer_sizes = [50, 500, 50, len(expansion_block)] # These are same as the original

    hybrid_network = HybridNetwork(layer_sizes, n_class, stdp_block_idx, stdp_learning_rate, stdp_tau_combined, burn_in=50).to(device)
    hybrid_network.load_state_dict(file_contents)

    first_block = np.squeeze(hybrid_network.blocks[0].synapse.weight.data.cpu().numpy())
    OR_assignment = [np.argmax(i) for i in first_block]
    ORN_first_three = [[i[-1], i[-2], i[-3]] for i in np.sort(first_block)]

    
    
    second_block = np.squeeze(hybrid_network.blocks[1].synapse.weight.data.cpu().numpy())
    PN_gloscores = np.zeros(len(second_block))
    for PN_index, PN in enumerate(second_block):
        # Each PN needs its own ORN ranking
        second_block_ORN_weights = second_block[PN_index]
        average_ORN_by_type = {}
        for OR_index in range(len(first_block[0])):
            # Each OR needs an average value
            total = []
            for i in range(len(OR_assignment)):
                # Each average comes from the assignment
                if OR_assignment[i] == OR_index:
                    total.append(second_block_ORN_weights[i])
            if len(total) != 0:
                average_ORN_by_type[OR_index] = sum(total)/len(total)
            else:
                average_ORN_by_type[OR_index] = 0
        # Sort the averages so we can take the last two
        sorted_averages = sorted(average_ORN_by_type.items(), key = lambda x: x[1])
        weight_1 = sorted_averages[-1][1]
        weight_2 = sorted_averages[-2][1]
        PN_gloscores[PN_index] = (weight_1-weight_2)/(weight_1+weight_2)
    gloscores_decolle.append(np.average(PN_gloscores))
    # sorted_gloscores = dict(sorted(gloscores.items(), key = lambda x: x[0]))
# Out:
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to1_30epochs_epoch_29.pt
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to10_30epochs_epoch_29.pt
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to50_30epochs_epoch_29.pt
# /home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to100_30epochs_epoch_29.pt

# %% [markdown]
# ## Plotting Gloscores

# %%
print("gloscores hybrid: ", gloscores_hybrid)
print("gloscores decolle: ", gloscores_decolle)
# Out:
# gloscores hybrid:  [0.1703359369821189, 0.1451115559935424, 0.11920174896794503, 0.1477152980662124]
# gloscores decolle:  [0.2105022286490254, 0.15723219550000156, 0.27253817341457526, 0.16962205158976176]

# %%
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the figure size according to your preference
bar_width = 0.35


ax.bar(range(len(gloscores_decolle)), gloscores_decolle, width= bar_width, label= "SNN - DECOLLE")
ax.bar(np.arange(len(gloscores_hybrid)) + bar_width, gloscores_hybrid, width= bar_width, label= "SNN - DECOLLE + STDP")

# ax.scatter(2, 0.8, marker= "s", label= "FNN", color= "green")
ax.axhline(0.8, linestyle='dashed', color="green", label= "ANN")


ax.set_ylim(0, 1)
ax.set_xlabel("Expansion Ratio")
ax.set_ylabel("GloScore")

ax.legend()

ax.set_xticks(range(len(gloscores_decolle)))
ax.set_xticklabels(['1:1', '1:10', '1:50', '1:100'])
ax.grid(True, linestyle='--', alpha=0.7)

plt.rc('font', size=12)
plt.rc('axes', titlesize=14)
plt.rc('axes', labelsize=12)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('legend', fontsize=10)


# ax.set_title("ORN-PN Connectome")
plt.savefig("ORN_PN_Connectome.png", dpi=300)

# Adjust layout for better spacing
plt.tight_layout()

# %% [markdown]
# ## Figure 4
#
# y-axis: K, dotted line fly, dotted line results FNN
#
# x-axis: expansion ratio

# %% [markdown]
# ### Addapt code from **GloScore**
#
# *K* is the average number of PN inputs per KC.
#
# PN inputs < 1/len(KC) = 0

# %%
# code from Laurens
import torch
file1to1 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to1_30epochs_epoch_29.pt"
file1to10 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to10_30epochs_epoch_29.pt"
file1to50 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to50_30epochs_epoch_29.pt"
file1to100 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to100_30epochs_epoch_29.pt"

# %%
file = file1to10 

file_contents = torch.load(f= file, map_location=torch.device('cpu'))
expansion_block = file_contents['blocks.2.synapse.weight']

# %%
print(expansion_block.shape)
# Out:
# torch.Size([500, 50, 1, 1, 1])

# %%
squeezed = expansion_block.squeeze()

print(squeezed.shape)
# Out:
# torch.Size([500, 50])

# %%
N = len(squeezed[:, 0])  # number of KC neurons

theta = 1/ N   # threshold below which synapse weights get set to 0

with_thereshold = torch.where(squeezed <= theta, 0, squeezed)

# %%
print("before threshold number non-zero:", torch.count_nonzero(squeezed))
print("after threshold applied number non-zero:", torch.count_nonzero(with_thereshold))

# i expect to see less values in the second print
# Out:
# before threshold number non-zero: tensor(25000)
# after threshold applied number non-zero: tensor(14815)

# %%
# good, move on

nonZero_perKC = []
for i in range(len(with_thereshold[:, 0])):
    nonZero_perKC.append(torch.count_nonzero(with_thereshold[i]))


avg_nonZero_perKC = sum(nonZero_perKC)/len(with_thereshold[:, 0])

print(avg_nonZero_perKC)
# Out:
# tensor(29.6300)

# %%
def get_K(file_params):
    file_contents = torch.load(f= file_params, map_location=torch.device('cpu'))
    expansion_block = file_contents['blocks.2.synapse.weight']
    squeezed = expansion_block.squeeze()

    N = len(squeezed[:, 0])  # number of KC neurons
    theta = 1/ N   # threshold below which synapse weights get set to 0
    with_thereshold = torch.where(squeezed <= theta, 0, squeezed)

    nonZero_perKC = []
    for i in range(len(with_thereshold[:, 0])):
        nonZero_perKC.append(torch.count_nonzero(with_thereshold[i]))

    avg_nonZero_perKC = sum(nonZero_perKC)/len(with_thereshold[:, 0])

    return float(avg_nonZero_perKC)

# %%
# code from Laurens
import torch
file1to1 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to1_30epochs_epoch_29.pt"
file1to10 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to10_30epochs_epoch_29.pt"
file1to50 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to50_30epochs_epoch_29.pt"
file1to100 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/network_1to100_30epochs_epoch_29.pt"


files = [file1to1, file1to10, file1to50, file1to100]

Ks_byExpansionRatio_hybrid = []

for file in files:
    Ks_byExpansionRatio_hybrid.append(get_K(file))

print(Ks_byExpansionRatio_hybrid)
# Out:
# [29.34000015258789, 29.6299991607666, 28.711599349975586, 28.31920051574707]

# %%
import torch
file1to1 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to1_30epochs_epoch_29.pt"
file1to10 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to10_30epochs_epoch_29.pt"
file1to50 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to50_30epochs_epoch_29.pt"
file1to100 = "/home/andrei/Desktop/COURSE_Neuromorphic_Computing/PROJECT/FOLDER_experiments/FIXED_local_tests/GOOD_TrainedData/DECOLLE/network_1to100_30epochs_epoch_29.pt"


files = [file1to1, file1to10, file1to50, file1to100]

Ks_byExpansionRatio_decolle = []

for file in files:
    Ks_byExpansionRatio_decolle.append(get_K(file))

print(Ks_byExpansionRatio_decolle)
# Out:
# [7.239999771118164, 40.597999572753906, 47.96200180053711, 48.9276008605957]

# %% [markdown]
# ### Plot Ks much like in Figure 3

# %%
Ks_AllConditions

# %%
fig, ax = plt.subplots(figsize=(8, 6))  # Adjust the figure size according to your preference
bar_width = 0.35


ax.bar(range(len(Ks_byExpansionRatio_decolle)), Ks_byExpansionRatio_decolle, width= bar_width, label= "SNN - DECOLLE", alpha= 0.85)
ax.bar(np.arange(len(Ks_byExpansionRatio_hybrid)) + bar_width, Ks_byExpansionRatio_hybrid, width= bar_width, label= "SNN - DECOLLE + STDP", alpha= 0.85)


# ax.scatter(2, 0.8, marker= "s", label= "FNN", color= "green")
ax.axhline(6, linestyle='dashed', color="red", label= "fly")
ax.axhline(3, linestyle='dashed', color="green", label= "ANN")
ax.axhline(7, linestyle='dashed', color="green")

ax.fill_between(range(-1, len(Ks_byExpansionRatio_hybrid) + 1), y1=3, y2=7, color="green", alpha=0.2)

ax.set_xlim(-1, 4)
# ax.set_ylim(0, 40)
ax.set_xlabel("Expansion Ratio")
ax.set_ylabel("K")

ax.legend()

ax.set_xticks(range(len(Ks_byExpansionRatio_hybrid)))
ax.set_xticklabels(['1:1', '1:10', '1:50', '1:100'])
ax.grid(True, linestyle='--', alpha=0.7)


plt.rc('font', size=12)
plt.rc('axes', titlesize=14)
plt.rc('axes', labelsize=12)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('legend', fontsize=10)


# ax.set_title("ORN-PN Connectome")
plt.savefig("KCInputDegree.png", dpi=300)

# Adjust layout for better spacing
plt.tight_layout()
